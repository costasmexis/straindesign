# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

RESPONSE_VARS = ['Limonene']

INPUT_VARS = ['ATOB_ECOLI','ERG8_YEAST','IDI_ECOLI',
                   'KIME_YEAST','MVD1_YEAST','Q40322_MENSP',
                   'Q8LKJ3_ABIGR','Q9FD86_STAAU','Q9FD87_STAAU']

DBTL_A = ['2X-Mh', 'B-Lm', '2X-Ll', 'A-Mm', 'B-Ll', 'A-Mh', '2X-Lm',
       'A-Hl', '2X-Hh', 'B-Ml', 'B-Mm', '2X-Lh', 'B-Mh', '2X-Hl', 'B-Hl',
       '2X-Ml', 'B-Hm', 'B-Lh', 'B-Hh', 'A-Ll', 'A-Hm', '2X-Mm', 'A-Hh',
       'A-Ml', 'A-Lm',  'A-Lh', '2X-Hm']

DBTL_B = ['BL-Mm', 'BL-Mh', 'BL-Ml']

# %% [markdown]
# ## Read and transform data

# %%
def read_data(path: str) -> pd.DataFrame:
    ''' Read data from csv file '''
    df = pd.read_csv(path, index_col=0)
    df = df[['Line Name', 'Type', '24.0']] # Keep only columns EDD style
    df = df.rename(columns={'24.0': 'value'}) # Rename 24.0 to value
    return df

def transform_data(df: pd.DataFrame) -> pd.DataFrame:
    ''' Get data to the right format for analysis '''
    new_columns = df['Type'].unique()
    data = pd.DataFrame()
    data.index = df['Line Name'].unique()
    # add new columns to data
    for col in new_columns:
        data[col] = 0.0
    # fill in data
    for l in data.index:
        for c in new_columns:
            value = df[(df['Line Name'] == l) & (df['Type'] == c)]['value'].values
            data.loc[l, c] = value
    # drop OD column
    data.drop('Optical Density', axis=1, inplace=True)
    return data

# %%
df = read_data('data/limonene_data.csv')
df = transform_data(df)
print(df.shape)
df.head()
# Out:
# (30, 10)
#        MVD1_YEAST  Q40322_MENSP  IDI_ECOLI  ATOB_ECOLI  Q8LKJ3_ABIGR  \
# 2X-Mh      2.1936      11.20370    3.18130      0.2384       0.29680
# B-Lm       0.9010       3.55060    1.06380      0.3550       0.28700
# BL-Mm      3.1930      11.31405    2.29065      1.2554       1.63235
# 2X-Ll      1.9367       3.06770    1.59950      0.0457       0.14230
# A-Mm       1.2638       6.78340    1.74950      1.4896       3.70420
#
#        Q9FD87_STAAU  Q9FD86_STAAU  KIME_YEAST  ERG8_YEAST   Limonene
# 2X-Mh       0.74880       0.78160      0.4010     0.94130   75.39261
# B-Lm        1.02540       0.89670      0.2006     0.50610   12.75786
# BL-Mm       0.41045       0.25975      1.0486     0.58985  119.81367
# 2X-Ll       0.12100       0.09980      0.2709     0.46910    5.98466
# A-Mm        5.13260       3.97700      0.3517     1.18100    9.66957

# %%
# DBTL 1st cycle
data_A = df[df.index.isin(DBTL_A)]
# DBTL 2st cycle
data_B = df[df.index.isin(DBTL_B)]
# Reorder columns based on specific order
data_A = data_A[INPUT_VARS + RESPONSE_VARS]
data_B = data_B[INPUT_VARS + RESPONSE_VARS]

# Save data to csv files
data_A.to_csv('data/data_A.csv')
data_B.to_csv('data/data_B.csv')

# %% [markdown]
# ## Basic statistical analysis on data

# %% [markdown]
# __Distribution of every column of the 2 cycles__

# %%
fig, axes = plt.subplots(4, 3, figsize=(20, 15))
for i, col in enumerate(data_A.columns):
    sns.histplot(data_A[col], ax=axes[i//3, i%3], bins=len(data_A), label='1st cycle', color='skyblue')
    sns.histplot(data_B[col], ax=axes[i//3, i%3], bins=len(data_B), label='2nd cycle', color='salmon')
    axes[i//3, i%3].set_title(col)
    axes[i//3, i%3].legend()
fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# __Limonene production__

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 3))
sns.boxplot(data=data_A, x='Limonene', ax=axes[0], color='skyblue')
sns.boxplot(data=data_B, x='Limonene', ax=axes[1], color='salmon')
axes[0].set_title('DBTL 1st cycle')
axes[1].set_title('DBTL 2st cycle')
fig.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# __PCA__

# %%
from sklearn.decomposition import PCA

def pca_analysis(df: pd.DataFrame, n_components=9):
    ''' Perform PCA analysis and plot results '''
    pca = PCA(n_components=n_components)
    pca_df = pd.DataFrame(pca.fit_transform(df.drop('Limonene', axis=1)))
    pca_df.index = df.index
    
    # Creating a figure with two subplots
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    # Scatter plot on the first subplot (axes[0])
    axes[0].scatter(pca_df[0], pca_df[1], s=df['Limonene']*2, color='blue', marker='x', alpha=0.5)
    axes[0].set_xlabel('PC1')
    axes[0].set_ylabel('PC2')
    axes[0].tick_params(labelsize=8)
    for i, txt in enumerate(pca_df.index):
        if df['Limonene'][i] > df['Limonene'].describe()["75%"]:
            axes[0].annotate(txt, (pca_df[0][i], pca_df[1][i]), xytext=(5, 5), 
                             textcoords='offset points', rotation=45)
    axes[0].set_title('Scatter Plot')

    # Bar plot on the second subplot (axes[1])
    pc_var = pca.explained_variance_ratio_
    pc_var = np.round(pc_var * 100, decimals=1)
    labels = ['PC' + str(x) for x in range(1, len(pc_var)+1)]
    axes[1].bar(x=range(1, len(pc_var)+1), height=pc_var, tick_label=labels)
    axes[1].set_ylabel('Percentage of Variance Explained')
    axes[1].set_xlabel('Principal Component')
    axes[1].set_title('Percentage of Variance Explained')

    plt.tight_layout()
    plt.show()

    return pca_df, pca
    
pca_df, pca = pca_analysis(df)

# %%
# Split data_A to X & y
X = data_A.drop('Limonene', axis=1)
y = data_A['Limonene'].copy()

# %%
import optuna 
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

def objective(trial):
    C = trial.suggest_loguniform('C', 1e-1, 1e3)
    gamma = trial.suggest_loguniform('gamma', 1e-3, 1e3)
    kernel = trial.suggest_categorical('kernel', ['linear', 'rbf'])
    epsilon = trial.suggest_loguniform('epsilon', 1e-3, 1e3)
    
    svr = SVR(C=C, gamma=gamma, kernel=kernel, epsilon=epsilon)
    scores = cross_val_score(svr, X, y, cv=5, scoring='neg_mean_absolute_error')
    return -scores.mean()

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
best_params = study.best_params
best_svr = SVR(**best_params)
# Out:
# [I 2023-12-06 13:46:34,621] A new study created in memory with name: no-name-328ed4fe-d353-4683-a591-33b006b94712
# [I 2023-12-06 13:46:34,642] Trial 0 finished with value: 14.5411795234892 and parameters: {'C': 16.185302034791636, 'gamma': 0.010806379670485287, 'kernel': 'linear', 'epsilon': 3.5457291349347435}. Best is trial 0 with value: 14.5411795234892.
# [I 2023-12-06 13:46:36,058] Trial 52 finished with value: 13.535436247407668 and parameters: {'C': 4.743520852892748, 'gamma': 0.002180718180804658, 'kernel': 'linear', 'epsilon': 0.003721505726269912}. Best is trial 28 with value: 13.481303921176021.
# [I 2023-12-06 13:46:36,085] Trial 53 finished with value: 13.720958479191143 and parameters: {'C': 1.8142564884671701, 'gamma': 0.0019331053163258842, 'kernel': 'linear', 'epsilon': 0.0021507508021078553}. Best is trial 28 with value: 13.481303921176021.
# [I 2023-12-06 13:46:36,110] Trial 54 finished with value: 13.793106991296835 and parameters: {'C': 1.069090182624489, 'gamma': 0.007719938780107134, 'kernel': 'linear', 'epsilon': 0.009916098901955083}. Best is trial 28 with value: 13.481303921176021.
# [I 2023-12-06 13:46:36,137] Trial 55 finished with value: 13.481255712422017 and parameters: {'C': 3.23658669814867, 'gamma': 0.001584843090134224, 'kernel': 'linear', 'epsilon': 0.034351311623686896}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,163] Trial 56 finished with value: 13.606473084332407 and parameters: {'C': 8.088588234550526, 'gamma': 0.006448074347546188, 'kernel': 'linear', 'epsilon': 0.0333049838965872}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,191] Trial 57 finished with value: 14.812442151599607 and parameters: {'C': 21.932156353191257, 'gamma': 0.0011026188228683304, 'kernel': 'linear', 'epsilon': 0.09451087836967006}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,218] Trial 58 finished with value: 13.655707364392134 and parameters: {'C': 1.933095814815454, 'gamma': 0.013337003318291294, 'kernel': 'linear', 'epsilon': 0.004313097952666956}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,244] Trial 59 finished with value: 13.814711879184207 and parameters: {'C': 2.9909924530026384, 'gamma': 0.0030170979873711166, 'kernel': 'linear', 'epsilon': 0.7496408965865059}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,271] Trial 60 finished with value: 13.805816271573084 and parameters: {'C': 1.0580088810233341, 'gamma': 0.025367805174063746, 'kernel': 'linear', 'epsilon': 0.008172771869950574}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,296] Trial 61 finished with value: 13.487991997029965 and parameters: {'C': 3.3477890310161973, 'gamma': 0.0017329581091149204, 'kernel': 'linear', 'epsilon': 0.0018053320011272027}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,322] Trial 62 finished with value: 13.487566600530727 and parameters: {'C': 3.4083676296048537, 'gamma': 0.0033393712827591957, 'kernel': 'linear', 'epsilon': 0.0017042425338460751}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,347] Trial 63 finished with value: 13.528008235282504 and parameters: {'C': 5.127631056987529, 'gamma': 0.005723824580253476, 'kernel': 'linear', 'epsilon': 0.003591911664166757}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,373] Trial 64 finished with value: 13.561779054738555 and parameters: {'C': 2.0880080801722833, 'gamma': 0.001603226463463298, 'kernel': 'linear', 'epsilon': 0.006130708781228896}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,398] Trial 65 finished with value: 13.518979568698935 and parameters: {'C': 5.165340006326868, 'gamma': 0.002516867198567377, 'kernel': 'linear', 'epsilon': 0.011834389916501178}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,426] Trial 66 finished with value: 13.491776668781185 and parameters: {'C': 2.474897979314574, 'gamma': 0.004727933770432699, 'kernel': 'linear', 'epsilon': 0.0019380868381732113}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,455] Trial 67 finished with value: 13.574861334942295 and parameters: {'C': 7.589523432904503, 'gamma': 0.001393264560051737, 'kernel': 'linear', 'epsilon': 0.0031906072381251453}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,481] Trial 68 finished with value: 18.781883932573873 and parameters: {'C': 11.514202121751328, 'gamma': 0.010715455967067968, 'kernel': 'rbf', 'epsilon': 0.0010216338867873936}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,506] Trial 69 finished with value: 13.659499338345807 and parameters: {'C': 1.4695689446056308, 'gamma': 0.003485073593310374, 'kernel': 'linear', 'epsilon': 0.02006349515042794}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,532] Trial 70 finished with value: 13.508974766816658 and parameters: {'C': 4.223933556732188, 'gamma': 0.006837904833180828, 'kernel': 'linear', 'epsilon': 0.007053019477561405}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,558] Trial 71 finished with value: 13.488159333834052 and parameters: {'C': 3.3365628401351377, 'gamma': 0.0032431587456098667, 'kernel': 'linear', 'epsilon': 0.0015018054656101216}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,585] Trial 72 finished with value: 13.495419700533551 and parameters: {'C': 2.236068657119755, 'gamma': 0.0010078829537459688, 'kernel': 'linear', 'epsilon': 0.001636862007146644}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,611] Trial 73 finished with value: 13.48893270144448 and parameters: {'C': 2.9938510625754216, 'gamma': 0.002469167865634864, 'kernel': 'linear', 'epsilon': 0.0028859793052869167}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,644] Trial 74 finished with value: 13.535974177196717 and parameters: {'C': 6.476971720411956, 'gamma': 0.004422365797484677, 'kernel': 'linear', 'epsilon': 0.0014445644871461415}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,674] Trial 75 finished with value: 13.494334536718435 and parameters: {'C': 3.9325088420178704, 'gamma': 0.0015618429201549797, 'kernel': 'linear', 'epsilon': 0.0041126702948765725}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,701] Trial 76 finished with value: 13.49055212986725 and parameters: {'C': 2.572067440003943, 'gamma': 0.006474944466797946, 'kernel': 'linear', 'epsilon': 0.0024821888556963248}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,728] Trial 77 finished with value: 13.518051912335888 and parameters: {'C': 5.1455270932602994, 'gamma': 0.018864410549919212, 'kernel': 'linear', 'epsilon': 0.012875725176397516}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,757] Trial 78 finished with value: 13.728397957683438 and parameters: {'C': 1.8004405997490243, 'gamma': 0.0034737469613683376, 'kernel': 'linear', 'epsilon': 0.0015435477448959723}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,785] Trial 79 finished with value: 21.370228098123086 and parameters: {'C': 3.7161454798968685, 'gamma': 0.009840881164529391, 'kernel': 'rbf', 'epsilon': 0.005427105339789997}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,813] Trial 80 finished with value: 13.615857401781966 and parameters: {'C': 8.424519042962132, 'gamma': 0.0018533430331770504, 'kernel': 'linear', 'epsilon': 0.0010034080234517947}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,841] Trial 81 finished with value: 13.48833696042885 and parameters: {'C': 3.2974945463426253, 'gamma': 0.0014748829423753007, 'kernel': 'linear', 'epsilon': 0.0018323437445277803}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,873] Trial 82 finished with value: 13.489247471552645 and parameters: {'C': 3.1492997909461717, 'gamma': 0.0027094813620916576, 'kernel': 'linear', 'epsilon': 0.002404224415485192}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,910] Trial 83 finished with value: 13.526988853566502 and parameters: {'C': 6.127591007586676, 'gamma': 0.0021791939822255377, 'kernel': 'linear', 'epsilon': 0.0016986611977111423}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,943] Trial 84 finished with value: 13.500086766976619 and parameters: {'C': 2.401274368268458, 'gamma': 0.004437823518234571, 'kernel': 'linear', 'epsilon': 0.007476813746967401}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:36,977] Trial 85 finished with value: 13.536959866621254 and parameters: {'C': 4.76716508411052, 'gamma': 0.0014488472106071073, 'kernel': 'linear', 'epsilon': 0.003321836897868708}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,012] Trial 86 finished with value: 13.599494592348767 and parameters: {'C': 1.243158935322768, 'gamma': 0.005882561400324463, 'kernel': 'linear', 'epsilon': 0.004792643226229509}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,046] Trial 87 finished with value: 13.689786662363593 and parameters: {'C': 1.5164489830397911, 'gamma': 0.00202213898009767, 'kernel': 'linear', 'epsilon': 0.002193658793434098}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,083] Trial 88 finished with value: 13.48720045275527 and parameters: {'C': 3.5278343994084755, 'gamma': 0.003619346082748739, 'kernel': 'linear', 'epsilon': 0.0014383575851384949}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,121] Trial 89 finished with value: 13.510869231781692 and parameters: {'C': 4.279993784511364, 'gamma': 0.013463121037442804, 'kernel': 'linear', 'epsilon': 0.0012758449425144087}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,154] Trial 90 finished with value: 13.677529698876674 and parameters: {'C': 10.540048984112381, 'gamma': 0.008461577921763642, 'kernel': 'linear', 'epsilon': 0.0031050290671846225}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,185] Trial 91 finished with value: 13.488409689309503 and parameters: {'C': 2.8105603583360015, 'gamma': 0.0036656340839643807, 'kernel': 'linear', 'epsilon': 0.0014702592113555086}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,213] Trial 92 finished with value: 13.487043388342993 and parameters: {'C': 3.5243952701460404, 'gamma': 0.0011988836887310036, 'kernel': 'linear', 'epsilon': 0.0021742887009869594}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,243] Trial 93 finished with value: 13.625155193308851 and parameters: {'C': 1.9872780473193092, 'gamma': 0.0010225574291434032, 'kernel': 'linear', 'epsilon': 0.004940822910738706}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,271] Trial 94 finished with value: 13.518877332940757 and parameters: {'C': 6.239972391743088, 'gamma': 0.0026335998820308498, 'kernel': 'linear', 'epsilon': 0.008473292963443395}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,297] Trial 95 finished with value: 13.48693223595941 and parameters: {'C': 3.513248758621998, 'gamma': 0.006070784421588376, 'kernel': 'linear', 'epsilon': 0.0024982396860153307}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,324] Trial 96 finished with value: 20.980756236398452 and parameters: {'C': 7.611276569907056, 'gamma': 0.0052719662790013, 'kernel': 'rbf', 'epsilon': 0.004048450856613365}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,354] Trial 97 finished with value: 13.524179115044808 and parameters: {'C': 4.567958239543908, 'gamma': 0.001244126735305973, 'kernel': 'linear', 'epsilon': 0.002472235349570372}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,381] Trial 98 finished with value: 13.48565293358106 and parameters: {'C': 2.3290750787258014, 'gamma': 0.009029544672718798, 'kernel': 'linear', 'epsilon': 0.015159380236195464}. Best is trial 55 with value: 13.481255712422017.
# [I 2023-12-06 13:46:37,411] Trial 99 finished with value: 13.755364198543992 and parameters: {'C': 1.728164940831858, 'gamma': 0.016381123710642105, 'kernel': 'linear', 'epsilon': 0.015308815578257483}. Best is trial 55 with value: 13.481255712422017.

# %%
score = cross_val_score(best_svr, X, y, cv=5, scoring='neg_mean_absolute_error')
best_svr.fit(X, y)
print(f'AVG(MAE) = {np.abs(score.mean())}')
# Out:
# AVG(MAE) = 13.481255712422017

# %% [markdown]
# ## SHAP

# %%
import shap

explainer = shap.KernelExplainer(best_svr.predict, X)
shap_values = explainer.shap_values(X)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
# Plot feature importances based on shap values
shap.summary_plot(shap_values, X, plot_type='bar')
